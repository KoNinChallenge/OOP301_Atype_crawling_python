# %% [markdown]
# ### いつも感謝しております。 항상 감사드립니다.
#
# ### * 案内 안내
#
# OOP301_Atype_crawling_python
#
# ー＞ A type: 関数等は使用しない簡単なタイプ 함수등은 사용하지 않은 간단한 타입
#
#    ◎ Webスクレイピング、クローリング 크롤링
#
#         Webサイトから特定の情報を自動的に抽出するコンピュータソフトウェア技術のこと
#         웹사이트로부터 특정의 정보를 자동적으로 추출하는 컴퓨터 소프트 웨어 기술
#
#    ◎ 目的 목적：
#
#         WEB上のテキスト及び写真等を自動的に収集する。
#         웹상의 텍스트 및 사진 등을 자동적으로 수집한다.
#
# ### * 環境設定（インストール anaconda, jupyter notebook, Windows 11 Pro, 64 ビットを中心に設定します。）
# ### * 환경설정（인스톨은 anaconda, jupyter notebook, Windows 11 Pro, 64 비트를 중심으로 설정합니다.）
#
# ### 「 conda install selenium 」
#
#         互換性が問題になった場合は: conda install selenium==3.141.0
#         호환성이 문제가 되었을 때에는: conda install selenium==3.141.0
#
# ### *** License & Copyright　ライセンス＆著作権　라이센스 & 저작권
# - Prohibition of unauthorized reproduction and redistribution
# - It is prohibited to use for commercial purposes other than study purposes.
# - Please observe USA laws.
# - Please use this app responsibly.
# <br>
#
# - 無断転載及び再配布等禁止
# - 勉強目的以外に商用目的で使用するのは禁止です。
# - 日本の法律をお守りください。
# - 責任を持ってこのアプリを使用してください。
# <br>
#
# - 무단전재 및 재배포등 금지
# - 공부 목적 이외에 상용목적으로 사용하는 것을 금지합니다.
# - 한국의 법률을 지켜 주세요.
# - 책임을 갖고 이 어플리를 사용해 주세요.
#
# Thank you so much! Good Luck!
# 助かりました。ありがとうございます。宜しくお願い致します。
# 도와주셔서 감사합니다. 잘부탁드립니다.

# %%
### Header-import ###
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import urllib.request

#「shift+enter」キーを押してください。「shift+enter」키를 눌러주세요.
# 上記の方法でできない場合はメニューバーの「Kernel」をクリックし、「Restart & Run All」をクリックしてください。
# 위의 방법으로 작동하지 않을 때에는 메뉴바의 「Kernel」을 클릭하고,「Restart & Run All」를 눌러주세요.

# %%
### Control: 変数・引数等 -> 検索キーワード及びイメージの枚数等を選択 ###
### Control: 변수, 인수등 -> 검색키워드 및 이미지의 매수등을 선택 ###
keyword = str(input("検索キーワードを入力してください。검색어를 입력해 주세요.>>> "))

# 入力ミスした場合の対応 입력 실수를 했을 때의 대응
while True:
    count_no =int(input("イメージの枚数を入力してください。이미지의 매수를 입력해 주세요.>>> "))
    if count_no <= 0:
        print('\033[31m' + "不正な値です。0以外の定数を入力してください。잘못된 값입니다. 0이외의 정수를 입력해 주세요." + '\033[0m')#文字の色を赤に設定 문자의 색을 설정
        continue
    break

##問題解決 Debugのためのコード  문제해결 Debug을 위한 코드
#debug_jump = []#NG urlの"img#imgrc="以降をstrで記入　NG url의"img#imgrc="이후를str로 기입

### BODY ###
# Google Chromeで自動化 Google Chrome으로 자동화
driver = webdriver.Chrome()
driver.get("https://www.google.co.jp/imghp?hl=ja&ogbl")

# Nameで検索 Name로 검색
elem = driver.find_element(By.NAME, "q")
elem.send_keys(keyword)
elem.send_keys(Keys.ENTER)

## スクロールダウンのセット 스크롤 다운 셋팅 ##
# Time sleep setting(seconds)
SCROLL_PAUSE = 1

# スクロールの高さをゲット 스크롤의 높이값을 get
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 一番下までスクロールダウン 바닥까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 時間調整 시간조정
    time.sleep(SCROLL_PAUSE)

    # 新スクロールの高さと既存のスクロールの高さを比較 새로운 스크롤의 높이값과 기존 스크롤의 높이값을 비교
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        try:
            driver.find_element(By.CSS_SELECTOR, '.mye4qd').click()
        except:
            break
        
    last_height = new_height

## イメージクリック及び保存 이미지 클릭 및 보존 ##
images = driver.find_elements_by_css_selector('.wXeWr.islib.nfEiy')

count = 1
for image in images:
    try:
        image.click()
        
#         #ブロック、著作権等の対応 デバッグ 블록, 저작권등에 대한 대응 디버그
#         current_url = driver.current_url
#         debug_url = current_url.split("img#imgrc=")[-1]
#         if debug_jump[1] == debug_url:
#             print("+++JUMP!+++")
#             continue
        
        time.sleep(2)
        
        imgURL = driver.find_element_by_xpath("/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div[2]/div/div[2]/div[2]/div[2]/c-wiz/div/div/div/div[3]/div[1]/a/img[1]").get_attribute('src')
        img_path_file = f'{keyword}{str(count)}.jpg'
        
        # 403 forbidden Debug
        opener=urllib.request.build_opener()
        opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
        urllib.request.install_opener(opener)
       
        urllib.request.urlretrieve(imgURL, img_path_file)
        
        count += 1
        
        # 中間報告 중간 보고
        if count == count_no/2:
            print("***")
            print(f"合計{count_n
            
        # 枚数ストップ 매수 스탑
        if count > count_no:
            print("*****************************")
            print(f"おめでとうございます！축하합니다! \n「{keyword}」イメージを【{count_no}枚】保存しました。「{keyword}」이미지를【{count_no}장】보존했습니다.")
            print("*****************************")
            break
            
    except Exception as e:
        #print('==== エラー内容 에러 내용 ====') #Debugは大事なのでcheckが必要 Debug는 중요하기 때문에 확인이 필요
        #print('type:' + str(type(e)))
        #print('具体的な内容 구체적 내용:' + str(e))
        pass

driver.close()
# Out:
# 検索キーワードを入力してください。검색어를 입력해 주세요.>>> リンゴ
# イメージの枚数を入力してください。이미지의 매수를 입력해 주세요.>>> 10
# ***
# 合計10枚の半分 【5枚】完了しました。합계10장의 절반【5장】완료했습니다.
# ***
# *****************************
# おめでとうございます！축하합니다!
# 「リンゴ」イメージを【10枚】保存しました。「リンゴ」이미지를【10장】보존했습니다.
# *****************************
